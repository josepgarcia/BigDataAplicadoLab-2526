# %% [markdown]
# # Notebook de pruebas PySpark
# Verificación rápida de entorno y operaciones básicas.

# %%
import sys
print('Python:', sys.version)
import pyspark
print('PySpark:', pyspark.__version__)

# %%
print('Suma ejemplo:', 2 + 3)
